# %%
using Pkg

# %%
Pkg.add("DataFrames")
# Out:
#    Resolving package versions...
#    Installed InlineStrings ────── v1.4.3
#    Installed SentinelArrays ───── v1.4.8
#    Installed LaTeXStrings ─────── v1.4.0
#    Installed InvertedIndices ──── v1.3.1
#    Installed Tables ───────────── v1.12.0
#    Installed OrderedCollections ─ v1.8.0
#    Installed PrettyTables ─────── v2.4.0
#    Installed DataFrames ───────── v1.7.0
#    Installed Statistics ───────── v1.11.1
#    Installed Compat ───────────── v4.16.0
#    Installed StringManipulation ─ v0.4.1
#    Installed DataStructures ───── v0.18.20
#    Installed Missings ─────────── v1.2.0
#     Updating `C:\Users\kzaja\.julia\environments\v1.11\Project.toml`
#   [a93c6f00] + DataFrames v1.7.0
#     Updating `C:\Users\kzaja\.julia\environments\v1.11\Manifest.toml`
#   [34da2185] + Compat v4.16.0
#   [a8cc5b0e] + Crayons v4.1.1
#   [9a962f9c] + DataAPI v1.16.0
#   [a93c6f00] + DataFrames v1.7.0
#   [864edb3b] + DataStructures v0.18.20
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [842dd82b] + InlineStrings v1.4.3
#   [41ab1584] + InvertedIndices v1.3.1
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [b964fa9f] + LaTeXStrings v1.4.0
#   [e1d29d7a] + Missings v1.2.0
#   [bac558e1] + OrderedCollections v1.8.0
#   [2dfb63ee] + PooledArrays v1.4.3
#   [08abe8d2] + PrettyTables v2.4.0
#   [189a3867] + Reexport v1.2.2
#   [91c51154] + SentinelArrays v1.4.8
#   [a2af1166] + SortingAlgorithms v1.2.1
#   [10745b16] + Statistics v1.11.1
#   [892a3eda] + StringManipulation v0.4.1
#   [3783bdb8] + TableTraits v1.0.1
#   [bd369af6] + Tables v1.12.0
#   [9fa8497b] + Future v1.11.0
#   [37e2e46d] + LinearAlgebra v1.11.0
#   [e66e0078] + CompilerSupportLibraries_jll v1.1.1+0
#   [4536629a] + OpenBLAS_jll v0.3.27+1
#   [8e850b90] + libblastrampoline_jll v5.11.0+0
#  project...ecompiling
#     516.5 ms  ✓ Reexport
#     546.9 ms  ✓ DataValueInterfaces
#     541.5 ms  ✓ LaTeXStrings
#     542.5 ms  ✓ InvertedIndices
#     889.8 ms  ✓ OrderedCollections
#     757.7 ms  ✓ Statistics
#     882.9 ms  ✓ InlineStrings
#     585.5 ms  ✓ IteratorInterfaceExtensions
#     580.0 ms  ✓ DataAPI
#     882.8 ms  ✓ Compat
#     632.2 ms  ✓ TableTraits
#     989.9 ms  ✓ InlineStrings → ParsersExt
#     831.1 ms  ✓ PooledArrays
#    1711.0 ms  ✓ Crayons
#     732.9 ms  ✓ Missings
#     635.0 ms  ✓ Compat → CompatLinearAlgebraExt
#    1834.4 ms  ✓ SentinelArrays
#    1001.2 ms  ✓ Tables
#    2316.0 ms  ✓ StringManipulation
#    1578.9 ms  ✓ DataStructures
#     572.0 ms  ✓ SortingAlgorithms
#   13042.1 ms  ✓ PrettyTables
#   28884.5 ms  ✓ DataFrames
#   23 dependencies successfully precompiled in 46 seconds. 45 already precompiled.

# %%
using DataFrames

# %%
Pkg.add("CSV")
# Out:
#    Resolving package versions...
#    Installed CodecZlib ────────── v0.7.8
#    Installed TranscodingStreams ─ v0.11.3
#    Installed FilePathsBase ────── v0.9.23
#    Installed CSV ──────────────── v0.10.15
#     Updating `C:\Users\kzaja\.julia\environments\v1.11\Project.toml`
#   [336ed68f] + CSV v0.10.15
#     Updating `C:\Users\kzaja\.julia\environments\v1.11\Manifest.toml`
#   [336ed68f] + CSV v0.10.15
#   [944b1d66] + CodecZlib v0.7.8
#   [48062228] + FilePathsBase v0.9.23
#   [3bb67fe8] + TranscodingStreams v0.11.3
#   [ea10d353] + WeakRefStrings v1.4.2
#   [76eceee3] + WorkerUtilities v1.6.1
# Precompiling project...
#     527.5 ms  ✓ WorkerUtilities
#     611.2 ms  ✓ TranscodingStreams
#     904.9 ms  ✓ WeakRefStrings
#     547.2 ms  ✓ CodecZlib
#    1200.7 ms  ✓ FilePathsBase
#     615.9 ms  ✓ FilePathsBase → FilePathsBaseMmapExt
#    1304.8 ms  ✓ FilePathsBase → FilePathsBaseTestExt
#   11114.4 ms  ✓ CSV
#   8 dependencies successfully precompiled in 14 seconds. 68 already precompiled.

# %%
using CSV

# %%
Pkg.add("Plots")
# Out:
#    Resolving package versions...
#    Installed JpegTurbo_jll ───────────── v3.1.1+0
#    Installed libdecor_jll ────────────── v0.2.2+0
#    Installed GR_jll ──────────────────── v0.73.13+0
#    Installed Libmount_jll ────────────── v2.40.3+0
#    Installed libfdk_aac_jll ──────────── v2.0.3+0
#    Installed LoggingExtras ───────────── v1.1.0
#    Installed LERC_jll ────────────────── v4.0.1+0
#    Installed Opus_jll ────────────────── v1.3.3+0
#    Installed Xorg_xkbcomp_jll ────────── v1.4.6+1
#    Installed Unitful ─────────────────── v1.22.0
#    Installed OpenSSL ─────────────────── v1.4.3
#    Installed ConcurrentUtilities ─────── v2.5.0
#    Installed Xorg_libpthread_stubs_jll ─ v0.1.2+0
#    Installed PlotUtils ───────────────── v1.4.3
#    Installed HTTP ────────────────────── v1.10.15
#    Installed Contour ─────────────────── v0.6.3
#    Installed Cairo_jll ───────────────── v1.18.2+1
#    Installed Xorg_libSM_jll ──────────── v1.2.4+0
#    Installed Libgpg_error_jll ────────── v1.51.1+0
#    Installed Fontconfig_jll ──────────── v2.15.0+0
#    Installed Xorg_libxkbfile_jll ─────── v1.1.2+1
#    Installed Xorg_libXinerama_jll ────── v1.1.5+0
#    Installed FFMPEG ──────────────────── v0.4.2
#    Installed EpollShim_jll ───────────── v0.0.20230411+1
#    Installed Pango_jll ───────────────── v1.56.1+0
#    Installed Bzip2_jll ───────────────── v1.0.9+0
#    Installed IrrationalConstants ─────── v0.2.4
#    Installed PtrArrays ───────────────── v1.3.0
#    Installed SimpleBufferStream ──────── v1.2.0
#    Installed XZ_jll ──────────────────── v5.6.4+1
#    Installed HarfBuzz_jll ────────────── v8.5.0+0
#    Installed xkbcommon_jll ───────────── v1.4.1+2
#    Installed Xorg_libXau_jll ─────────── v1.0.12+0
#    Installed PlotThemes ──────────────── v3.3.0
#    Installed NaNMath ─────────────────── v1.1.2
#    Installed ColorSchemes ────────────── v3.29.0
#    Installed FriBidi_jll ─────────────── v1.0.16+0
#    Installed fzf_jll ─────────────────── v0.56.3+0
#    Installed LZO_jll ─────────────────── v2.10.3+0
#    Installed JLFzf ───────────────────── v0.1.9
#    Installed libpng_jll ──────────────── v1.6.46+0
#    Installed StatsBase ───────────────── v0.34.4
#    Installed FreeType2_jll ───────────── v2.13.3+1
#    Installed Xorg_libxcb_jll ─────────── v1.17.0+3
#    Installed Colors ──────────────────── v0.13.0
#    Installed GLFW_jll ────────────────── v3.4.0+2
#    Installed ExceptionUnwrapping ─────── v0.1.11
#    Installed libaom_jll ──────────────── v3.11.0+0
#    Installed gperf_jll ───────────────── v3.1.1+1
#    Installed Dbus_jll ────────────────── v1.14.10+0
#    Installed ColorTypes ──────────────── v0.12.0
#    Installed Xorg_libXext_jll ────────── v1.3.6+3
#    Installed Zstd_jll ────────────────── v1.5.7+0
#    Installed GR ──────────────────────── v0.73.13
#    Installed Libtiff_jll ─────────────── v4.7.1+0
#    Installed Expat_jll ───────────────── v2.6.5+0
#    Installed Format ──────────────────── v1.3.7
#    Installed Plots ───────────────────── v1.40.9
#    Installed ColorVectorSpace ────────── v0.11.0
#    Installed Xorg_libXi_jll ──────────── v1.8.2+0
#    Installed Libffi_jll ──────────────── v3.2.2+2
#    Installed Xorg_libXrender_jll ─────── v0.9.11+1
#    Installed XSLT_jll ────────────────── v1.1.42+0
#    Installed Qt6ShaderTools_jll ──────── v6.7.1+1
#    Installed Qt6Declarative_jll ──────── v6.7.1+2
#    Installed AliasTables ─────────────── v1.1.3
#    Installed LogExpFunctions ─────────── v0.3.29
#    Installed MacroTools ──────────────── v0.5.15
#    Installed Xorg_libXcursor_jll ─────── v1.2.3+0
#    Installed Libuuid_jll ─────────────── v2.40.3+0
#    Installed Wayland_protocols_jll ───── v1.36.0+0
#    Installed Xorg_libICE_jll ─────────── v1.1.1+0
#    Installed Graphite2_jll ───────────── v1.3.14+1
#    Installed StableRNGs ──────────────── v1.0.2
#    Installed libass_jll ──────────────── v0.15.2+0
#    Installed XML2_jll ────────────────── v2.13.6+0
#    Installed Pixman_jll ──────────────── v0.43.4+0
#    Installed Wayland_jll ─────────────── v1.21.0+2
#    Installed Xorg_xtrans_jll ─────────── v1.5.1+0
#    Installed OpenSSL_jll ─────────────── v3.0.16+0
#    Installed BitFlags ────────────────── v0.1.9
#    Installed Libgcrypt_jll ───────────── v1.11.0+0
#    Installed Latexify ────────────────── v0.16.6
#    Installed LLVMOpenMP_jll ──────────── v18.1.7+0
#    Installed Xorg_libXrandr_jll ──────── v1.5.4+0
#    Installed Xorg_libXfixes_jll ──────── v6.0.0+0
#    Installed FixedPointNumbers ───────── v0.8.5
#    Installed LAME_jll ────────────────── v3.100.2+0
#    Installed Qt6Wayland_jll ──────────── v6.7.1+1
#    Installed Libiconv_jll ────────────── v1.18.0+0
#    Installed Qt6Base_jll ─────────────── v6.7.1+1
#    Installed Glib_jll ────────────────── v2.82.4+0
#    Installed libvorbis_jll ───────────── v1.3.7+2
#    Installed Xorg_libX11_jll ─────────── v1.8.6+3
#    Installed Libglvnd_jll ────────────── v1.7.0+0
#    Installed Xorg_libXdmcp_jll ───────── v1.1.5+0
#    Installed UnitfulLatexify ─────────── v1.6.4
#     Updating `C:\Users\kzaja\.julia\environments\v1.11\Project.toml`
#   [91a5bcdd] + Plots v1.40.9
#     Updating `C:\Users\kzaja\.julia\environments\v1.11\Manifest.toml`
#   [66dad0bd] + AliasTables v1.1.3
#   [d1d4a3ce] + BitFlags v0.1.9
#  [35d6a980] + ColorSchemes v3.29.0
#   [3da002f7] + ColorTypes v0.12.0
#   [c3611d14] + ColorVectorSpace v0.11.0
#   [5ae59095] + Colors v0.13.0
#   [f0e56b4a] + ConcurrentUtilities v2.5.0
#   [d38c429a] + Contour v0.6.3
#   [8bb1440f] + DelimitedFiles v1.9.1
#   [ffbed154] + DocStringExtensions v0.9.3
#   [460bff9d] + ExceptionUnwrapping v0.1.11
#   [c87230d0] + FFMPEG v0.4.2
#   [53c48c17] + FixedPointNumbers v0.8.5
#   [1fa38f19] + Format v1.3.7
#   [28b8d3ca] + GR v0.73.13
#   [42e2da0e] + Grisu v1.0.2
#   [cd3eb016] + HTTP v1.10.15
#   [92d709cd] + IrrationalConstants v0.2.4
#   [1019f520] + JLFzf v0.1.9
#   [23fbe1c1] + Latexify v0.16.6
#   [2ab3a3ac] + LogExpFunctions v0.3.29
#   [e6f89c97] + LoggingExtras v1.1.0
#   [1914dd2f] + MacroTools v0.5.15
#   [442fdcdd] + Measures v0.3.2
#   [77ba4419] + NaNMath v1.1.2
#   [4d8831e6] + OpenSSL v1.4.3
#   [b98c9c47] + Pipe v1.3.0
#   [ccf2f8ad] + PlotThemes v3.3.0
#   [995b91a9] + PlotUtils v1.4.3
#   [91a5bcdd] + Plots v1.40.9
#   [43287f4e] + PtrArrays v1.3.0
#   [3cdcf5f2] + RecipesBase v1.3.4
#   [01d81517] + RecipesPipeline v0.6.12
#   [05181044] + RelocatableFolders v1.0.1
#   [ae029012] + Requires v1.3.0
#   [6c6a2e73] + Scratch v1.2.1
#   [992d4aef] + Showoff v1.0.3
#   [777ac1f9] + SimpleBufferStream v1.2.0
#   [860ef19b] + StableRNGs v1.0.2
#   [82ae8749] + StatsAPI v1.7.0
#   [2913bbd2] + StatsBase v0.34.4
#   [62fd8b95] + TensorCore v0.1.1
#   [5c2747f8] + URIs v1.5.1
#   [1cfade01] + UnicodeFun v0.4.1
#   [1986cc42] + Unitful v1.22.0
#   [45397f5d] + UnitfulLatexify v1.6.4
#   [41fe7b60] + Unzip v0.2.0
#   [6e34b625] + Bzip2_jll v1.0.9+0
#   [83423d85] + Cairo_jll v1.18.2+1
#   [ee1fde0b] + Dbus_jll v1.14.10+0
#   [2702e6a9] + EpollShim_jll v0.0.20230411+1
#   [2e619515] + Expat_jll v2.6.5+0
# ⌅ [b22a6f82] + FFMPEG_jll v4.4.4+1
#   [a3f928ae] + Fontconfig_jll v2.15.0+0
#   [d7e528f0] + FreeType2_jll v2.13.3+1
#   [559328eb] + FriBidi_jll v1.0.16+0
#   [0656b61e] + GLFW_jll v3.4.0+2
#   [d2c73de3] + GR_jll v0.73.13+0
#   [78b55507] + Gettext_jll v0.21.0+0
#   [7746bdde] + Glib_jll v2.82.4+0
#   [3b182d85] + Graphite2_jll v1.3.14+1
#   [2e76f6c2] + HarfBuzz_jll v8.5.0+0
#   [aacddb02] + JpegTurbo_jll v3.1.1+0
#   [c1c5ebd0] + LAME_jll v3.100.2+0
#   [88015f11] + LERC_jll v4.0.1+0
#   [1d63c593] + LLVMOpenMP_jll v18.1.7+0
#   [dd4b983a] + LZO_jll v2.10.3+0
# ⌅ [e9f186c6] + Libffi_jll v3.2.2+2
#   [d4300ac3] + Libgcrypt_jll v1.11.0+0
#   [7e76a0d4] + Libglvnd_jll v1.7.0+0
#   [7add5ba3] + Libgpg_error_jll v1.51.1+0
#   [94ce4f54] + Libiconv_jll v1.18.0+0
#   [4b2f31a3] + Libmount_jll v2.40.3+0
#   [89763e89] + Libtiff_jll v4.7.1+0
#   [38a345b3] + Libuuid_jll v2.40.3+0
#   [e7412a2a] + Ogg_jll v1.3.5+1
#   [458c3c95] + OpenSSL_jll v3.0.16+0
#   [91d4177d] + Opus_jll v1.3.3+0
#   [36c8627f] + Pango_jll v1.56.1+0
# ⌅ [30392449] + Pixman_jll v0.43.4+0
# ⌅ [c0090381] + Qt6Base_jll v6.7.1+1
# ⌅ [629bc702] + Qt6Declarative_jll v6.7.1+2
# ⌅ [ce943373] + Qt6ShaderTools_jll v6.7.1+1
# ⌃ [e99dba38] + Qt6Wayland_jll v6.7.1+1
#   [a44049a8] + Vulkan_Loader_jll v1.3.243+0
#   [a2964d1f] + Wayland_jll v1.21.0+2
#   [2381bf8a] + Wayland_protocols_jll v1.36.0+0
#   [02c8fc9c] + XML2_jll v2.13.6+0
#   [aed1982a] + XSLT_jll v1.1.42+0
#   [ffd25f8a] + XZ_jll v5.6.4+1
#   [f67eecfb] + Xorg_libICE_jll v1.1.1+0
#   [c834827a] + Xorg_libSM_jll v1.2.4+0
#   [4f6342f7] + Xorg_libX11_jll v1.8.6+3
#   [0c0b7dd1] + Xorg_libXau_jll v1.0.12+0
#   [935fb764] + Xorg_libXcursor_jll v1.2.3+0
#   [a3789734] + Xorg_libXdmcp_jll v1.1.5+0
#   [1082639a] + Xorg_libXext_jll v1.3.6+3
#   [d091e8ba] + Xorg_libXfixes_jll v6.0.0+0
#   [a51aa0fd] + Xorg_libXi_jll v1.8.2+0
#   [d1454406] + Xorg_libXinerama_jll v1.1.5+0
#   [ec84b674] + Xorg_libXrandr_jll v1.5.4+0
#   [ea2f1a96] + Xorg_libXrender_jll v0.9.11+1
#   [14d82f49] + Xorg_libpthread_stubs_jll v0.1.2+0
#   [c7cfdc94] + Xorg_libxcb_jll v1.17.0+3
#   [cc61e674] + Xorg_libxkbfile_jll v1.1.2+1
#   [e920d4aa] + Xorg_xcb_util_cursor_jll v0.1.4+0
#   [12413925] + Xorg_xcb_util_image_jll v0.4.0+1
#   [2def613f] + Xorg_xcb_util_jll v0.4.0+1
#   [975044d2] + Xorg_xcb_util_keysyms_jll v0.4.0+1
#   [0d47668e] + Xorg_xcb_util_renderutil_jll v0.3.9+1
#   [c22f9ab0] + Xorg_xcb_util_wm_jll v0.4.1+1
#   [35661453] + Xorg_xkbcomp_jll v1.4.6+1
#   [33bec58e] + Xorg_xkeyboard_config_jll v2.39.0+0
#   [c5fb5394] + Xorg_xtrans_jll v1.5.1+0
#   [3161d3a3] + Zstd_jll v1.5.7+0
#   [35ca27e7] + eudev_jll v3.2.9+0
#   [214eeab7] + fzf_jll v0.56.3+0
#   [1a1c6b14] + gperf_jll v3.1.1+1
#   [a4ae2306] + libaom_jll v3.11.0+0
#   [0ac62f75] + libass_jll v0.15.2+0
#   [1183f4f0] + libdecor_jll v0.2.2+0
#   [2db6ffa8] + libevdev_jll v1.11.0+0
#   [f638f0a6] + libfdk_aac_jll v2.0.3+0
#   [36db933b] + libinput_jll v1.18.0+0
#   [b53b4c65] + libpng_jll v1.6.46+0
#   [f27f6e37] + libvorbis_jll v1.3.7+2
#   [009596ad] + mtdev_jll v1.1.6+0
# ⌅ [1270edf5] + x264_jll v2021.5.5+0
# ⌅ [dfaa095f] + x265_jll v3.5.0+0
#   [d8fb68d0] + xkbcommon_jll v1.4.1+2
#   [2f01184e] + SparseArrays v1.11.0
#   [05823500] + OpenLibm_jll v0.8.1+2
#   [efcefdf7] + PCRE2_jll v10.42.0+1
#   [bea87d4a] + SuiteSparse_jll v7.7.0+0
#         Info Packages marked with ⌃ and ⌅ have new versions available. Those with ⌃ may be upgradable, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#     586.2 ms  ✓ Pipe
#    1157.2 ms  ✓ TensorCore
#     668.3 ms  ✓ Contour
#     692.6 ms  ✓ StatsAPI
#     688.6 ms  ✓ Measures
#     634.0 ms  ✓ StableRNGs
#     801.8 ms  ✓ Requires
#     854.6 ms  ✓ Unzip
#    1675.8 ms  ✓ Format
#    1259.7 ms  ✓ Grisu
#     567.0 ms  ✓ SimpleBufferStream
#    1092.1 ms  ✓ PtrArrays
#    1340.5 ms  ✓ URIs
#    1926.4 ms  ✓ IrrationalConstants
#     961.3 ms  ✓ NaNMath
#     781.6 ms  ✓ DelimitedFiles
#    3168.5 ms  ✓ MacroTools
#     787.9 ms  ✓ BitFlags
#     929.0 ms  ✓ Scratch
#    1932.9 ms  ✓ Statistics → SparseArraysExt
#    1319.6 ms  ✓ ConcurrentUtilities
#     900.4 ms  ✓ LoggingExtras
#    1002.3 ms  ✓ DocStringExtensions
#    1065.5 ms  ✓ OpenSSL_jll
#    1007.2 ms  ✓ Graphite2_jll
#    1302.6 ms  ✓ ExceptionUnwrapping
#     936.2 ms  ✓ Libmount_jll
#    1120.3 ms  ✓ EpollShim_jll
#    1139.3 ms  ✓ LLVMOpenMP_jll
#    1101.8 ms  ✓ Bzip2_jll
#    3692.3 ms  ✓ FixedPointNumbers
#     981.0 ms  ✓ Xorg_libICE_jll
#    2900.9 ms  ✓ UnicodeFun
#    1128.2 ms  ✓ Xorg_libXau_jll
#    1299.0 ms  ✓ libpng_jll
#    1282.7 ms  ✓ libfdk_aac_jll
#    1273.7 ms  ✓ LERC_jll
#    1335.1 ms  ✓ LAME_jll
#    1259.6 ms  ✓ fzf_jll
#    1094.0 ms  ✓ JpegTurbo_jll
#     793.2 ms  ✓ mtdev_jll
#     776.2 ms  ✓ Xorg_libXdmcp_jll
#    1018.6 ms  ✓ XZ_jll
#     928.7 ms  ✓ Ogg_jll
#     885.8 ms  ✓ gperf_jll
#     908.0 ms  ✓ x265_jll
#     891.4 ms  ✓ x264_jll
#     931.0 ms  ✓ Zstd_jll
#     918.3 ms  ✓ libaom_jll
#     913.4 ms  ✓ Expat_jll
#     951.9 ms  ✓ LZO_jll
#    1006.0 ms  ✓ Xorg_xtrans_jll
#    1084.6 ms  ✓ Opus_jll
#    1029.0 ms  ✓ libevdev_jll
#    1104.1 ms  ✓ Libgpg_error_jll
#    1122.6 ms  ✓ Libffi_jll
#    1148.6 ms  ✓ Libiconv_jll
#     837.1 ms  ✓ Wayland_protocols_jll
#     840.6 ms  ✓ Xorg_libpthread_stubs_jll
#     854.8 ms  ✓ Libuuid_jll
#     741.1 ms  ✓ Showoff
#     936.4 ms  ✓ FriBidi_jll
#     861.5 ms  ✓ AliasTables
#     706.7 ms  ✓ RelocatableFolders
#     988.8 ms  ✓ LogExpFunctions
#    1035.2 ms  ✓ Pixman_jll
#    1048.4 ms  ✓ FreeType2_jll
#    2633.8 ms  ✓ RecipesBase
#    1109.7 ms  ✓ Xorg_libSM_jll
#    2592.9 ms  ✓ OpenSSL
#    1153.6 ms  ✓ libvorbis_jll
#    2420.9 ms  ✓ ColorTypes
#     841.7 ms  ✓ eudev_jll
#    1044.2 ms  ✓ Libtiff_jll
#     855.6 ms  ✓ Dbus_jll
#    4153.6 ms  ✓ Latexify
#    2271.4 ms  ✓ JLFzf
#    1069.8 ms  ✓ Libgcrypt_jll
#    1125.7 ms  ✓ XML2_jll
#    1353.1 ms  ✓ Fontconfig_jll
#    1338.2 ms  ✓ ColorTypes → StyledStringsExt
#     966.2 ms  ✓ libinput_jll
#    3054.0 ms  ✓ ColorVectorSpace
#    1280.5 ms  ✓ Latexify → SparseArraysExt
#    3515.0 ms  ✓ StatsBase
#     830.5 ms  ✓ Wayland_jll
#    1056.2 ms  ✓ Gettext_jll
#    1049.2 ms  ✓ XSLT_jll
#    2591.3 ms  ✓ Latexify → DataFramesExt
#     710.4 ms  ✓ Xorg_libxcb_jll
#    1110.9 ms  ✓ Glib_jll
#     960.0 ms  ✓ Xorg_xcb_util_jll
#     953.8 ms  ✓ Xorg_libX11_jll
#     923.3 ms  ✓ Xorg_xcb_util_keysyms_jll
#     932.3 ms  ✓ Xorg_xcb_util_image_jll
#     919.7 ms  ✓ Xorg_xcb_util_renderutil_jll
#     946.9 ms  ✓ Xorg_xcb_util_wm_jll
#    6569.0 ms  ✓ Colors
#     756.4 ms  ✓ Xorg_libXrender_jll
#     766.5 ms  ✓ Xorg_libXext_jll
#     865.3 ms  ✓ Xorg_libXfixes_jll
#     855.6 ms  ✓ Xorg_libxkbfile_jll
#     805.9 ms  ✓ Xorg_xcb_util_cursor_jll
#     905.7 ms  ✓ Xorg_libXinerama_jll
#     889.3 ms  ✓ Xorg_libXrandr_jll
#     934.1 ms  ✓ Libglvnd_jll
#    1311.5 ms  ✓ Cairo_jll
#     889.1 ms  ✓ Xorg_libXcursor_jll
#     935.5 ms  ✓ Xorg_libXi_jll
#     771.7 ms  ✓ Xorg_xkbcomp_jll
#    1126.1 ms  ✓ HarfBuzz_jll
#     719.8 ms  ✓ Xorg_xkeyboard_config_jll
#     791.6 ms  ✓ xkbcommon_jll
#    1058.1 ms  ✓ libass_jll
#    1123.5 ms  ✓ Pango_jll
#    1089.4 ms  ✓ Vulkan_Loader_jll
#     954.9 ms  ✓ libdecor_jll
#    4949.3 ms  ✓ ColorSchemes
#    2203.8 ms  ✓ FFMPEG_jll
#    1225.2 ms  ✓ GLFW_jll
#    2209.3 ms  ✓ Qt6Base_jll
#   28667.4 ms  ✓ Unitful
#    2521.5 ms  ✓ FFMPEG
#    1552.8 ms  ✓ Qt6ShaderTools_jll
#    1824.8 ms  ✓ GR_jll
#    2634.3 ms  ✓ UnitfulLatexify
#    2694.7 ms  ✓ Qt6Declarative_jll
#     636.1 ms  ✓ Qt6Wayland_jll
#   23673.7 ms  ✓ HTTP
#   13490.3 ms  ✓ PlotUtils
#    4861.2 ms  ✓ GR
#    3146.0 ms  ✓ PlotThemes
#    4243.5 ms  ✓ RecipesPipeline
#   53604.8 ms  ✓ Plots
#    4197.3 ms  ✓ Plots → UnitfulExt
#    4233.5 ms  ✓ Plots → IJuliaExt
#   136 dependencies successfully precompiled in 107 seconds. 80 already precompiled.

# %%
using Plots

# %%
Pkg.add("Interpolations")
# Out:
#    Resolving package versions...
#    Installed OffsetArrays ───── v1.15.0
#    Installed Adapt ──────────── v4.2.0
#    Installed StaticArraysCore ─ v1.4.3
#    Installed StaticArrays ───── v1.9.12
#    Installed ChainRulesCore ─── v1.25.1
#     Updating `C:\Users\kzaja\.julia\environments\v1.11\Project.toml`
#   [a98d9a8b] + Interpolations v0.15.1
#     Updating `C:\Users\kzaja\.julia\environments\v1.11\Manifest.toml`
#   [79e6a3ab] + Adapt v4.2.0
#   [13072b0f] + AxisAlgorithms v1.1.0
#   [d360d2e6] + ChainRulesCore v1.25.1
#   [a98d9a8b] + Interpolations v0.15.1
#   [6fe1bfb0] + OffsetArrays v1.15.0
#   [c84ed2f1] + Ratios v0.4.5
#   [90137ffa] + StaticArrays v1.9.12
#   [1e83bf80] + StaticArraysCore v1.4.3
#   [efce3f68] + WoodburyMatrices v1.0.0
#   [8ba89e20] + Distributed v1.11.0
#   [1a1011a3] + SharedArrays v1.11.0
#  project...ecompiling
#     555.1 ms  ✓ Ratios
#     602.3 ms  ✓ StaticArraysCore
#     688.3 ms  ✓ Adapt
#     932.4 ms  ✓ WoodburyMatrices
#     647.8 ms  ✓ Ratios → RatiosFixedPointNumbersExt
#    1362.4 ms  ✓ OffsetArrays
#     818.2 ms  ✓ Adapt → AdaptSparseArraysExt
#     819.5 ms  ✓ AxisAlgorithms
#     608.2 ms  ✓ OffsetArrays → OffsetArraysAdaptExt
#    1964.8 ms  ✓ ChainRulesCore
#     944.6 ms  ✓ ChainRulesCore → ChainRulesCoreSparseArraysExt
#    1828.8 ms  ✓ LogExpFunctions → LogExpFunctionsChainRulesCoreExt
#    7115.4 ms  ✓ StaticArrays
#     854.2 ms  ✓ Adapt → AdaptStaticArraysExt
#     862.3 ms  ✓ StaticArrays → StaticArraysStatisticsExt
#     910.3 ms  ✓ StaticArrays → StaticArraysChainRulesCoreExt
#    1971.6 ms  ✓ Interpolations
#    1426.5 ms  ✓ Interpolations → InterpolationsUnitfulExt
#   18 dependencies successfully precompiled in 13 seconds. 218 already precompiled.

# %%
using Interpolations

# %%
Pkg.add("Polynomials")
# Out:
#    Resolving package versions...
#    Installed ConstructionBase ─ v1.5.8
#    Installed Polynomials ────── v4.0.17
#     Updating `C:\Users\kzaja\.julia\environments\v1.11\Project.toml`
#   [f27b6e38] + Polynomials v4.0.17
#     Updating `C:\Users\kzaja\.julia\environments\v1.11\Manifest.toml`
#  [187b0558] + ConstructionBase v1.5.8
#   [f27b6e38] + Polynomials v4.0.17
#   [efcf1570] + Setfield v1.1.1
#  project...ecompiling
#     495.3 ms  ✓ ConstructionBase
#     449.5 ms  ✓ ConstructionBase → ConstructionBaseLinearAlgebraExt
#     845.2 ms  ✓ Unitful → ConstructionBaseUnitfulExt
#     879.8 ms  ✓ ConstructionBase → ConstructionBaseStaticArraysExt
#    1125.1 ms  ✓ Setfield
#   15198.8 ms  ✓ Polynomials
#    1146.5 ms  ✓ Polynomials → PolynomialsChainRulesCoreExt
#   7 dependencies successfully precompiled in 19 seconds. 236 already precompiled.

# %%
using Polynomials

# %%
Pkg.add("TaylorSeries")
# Out:
#    Resolving package versions...
#    Installed TaylorSeries ─ v0.18.3
#     Updating `C:\Users\kzaja\.julia\environments\v1.11\Project.toml`
#   [6aa5eb33] + TaylorSeries v0.18.3
#     Updating `C:\Users\kzaja\.julia\environments\v1.11\Manifest.toml`
#   [6aa5eb33] + TaylorSeries v0.18.3
# Precompiling project...
#    2379.5 ms  ✓ TaylorSeries
#     860.4 ms  ✓ TaylorSeries → TaylorSeriesSAExt
#   2 dependencies successfully precompiled in 4 seconds. 243 already precompiled.

# %%
using TaylorSeries

# %%
Pkg.add("SpecialPolynomials")
# Out:
#    Resolving package versions...
#    Installed HypergeometricFunctions ─ v0.3.27
#    Installed SpecialPolynomials ────── v0.4.11
#    Installed QuadGK ────────────────── v2.11.2
#    Installed SpecialFunctions ──────── v2.5.0
#    Installed OpenSpecFun_jll ───────── v0.5.6+0
#     Updating `C:\Users\kzaja\.julia\environments\v1.11\Project.toml`
#   [a25cea48] + SpecialPolynomials v0.4.11
#     Updating `C:\Users\kzaja\.julia\environments\v1.11\Manifest.toml`
#   [34004b35] + HypergeometricFunctions v0.3.27
#   [c03570c3] + Memoize v0.4.4
#   [1fd47b50] + QuadGK v2.11.2
#   [276daf66] + SpecialFunctions v2.5.0
#   [a25cea48] + SpecialPolynomials v0.4.11
#   [efe28fd5] + OpenSpecFun_jll v0.5.6+0
# Precompiling project...
#     406.1 ms  ✓ Memoize
#     607.2 ms  ✓ OpenSpecFun_jll
#    1013.2 ms  ✓ QuadGK
#    2154.0 ms  ✓ SpecialFunctions
#     790.0 ms  ✓ ColorVectorSpace → SpecialFunctionsExt
#    1152.5 ms  ✓ HypergeometricFunctions
#    1868.6 ms  ✓ SpecialFunctions → SpecialFunctionsChainRulesCoreExt
#    3716.2 ms  ✓ SpecialPolynomials
#   8 dependencies successfully precompiled in 8 seconds. 245 already precompiled.

# %%
using SpecialPolynomials

# %%
Pkg.add("QuadGK")
# Out:
#    Resolving package versions...
#     Updating `C:\Users\kzaja\.julia\environments\v1.11\Project.toml`
#   [1fd47b50] + QuadGK v2.11.2
#   No Changes to `C:\Users\kzaja\.julia\environments\v1.11\Manifest.toml`

# %%
using QuadGK

# %%
Pkg.add("FFTW")
# Out:
#    Resolving package versions...
#    Installed MKL_jll ───────── v2025.0.1+1
#    Installed FFTW_jll ──────── v3.3.10+3
#    Installed IntelOpenMP_jll ─ v2025.0.4+0
#    Installed oneTBB_jll ────── v2022.0.0+0
#    Installed FFTW ──────────── v1.8.1
#     Updating `C:\Users\kzaja\.julia\environments\v1.11\Project.toml`
#   [7a1cc6ca] + FFTW v1.8.1
#     Updating `C:\Users\kzaja\.julia\environments\v1.11\Manifest.toml`
#   [621f4979] + AbstractFFTs v1.5.0
#   [7a1cc6ca] + FFTW v1.8.1
#   [f5851436] + FFTW_jll v3.3.10+3
#   [1d5cc7b8] + IntelOpenMP_jll v2025.0.4+0
#   [856f044c] + MKL_jll v2025.0.1+1
#   [1317d2d5] + oneTBB_jll v2022.0.0+0
#   [4af54fe1] + LazyArtifacts v1.11.0
# Precompiling project...
#     656.2 ms  ✓ AbstractFFTs
#     770.7 ms  ✓ oneTBB_jll
#     735.9 ms  ✓ FFTW_jll
#     668.7 ms  ✓ AbstractFFTs → AbstractFFTsChainRulesCoreExt
#    1597.2 ms  ✓ IntelOpenMP_jll
#    1680.1 ms  ✓ AbstractFFTs → AbstractFFTsTestExt
#    3518.9 ms  ✓ MKL_jll
#    5777.7 ms  ✓ FFTW
#    1160.4 ms  ✓ Polynomials → PolynomialsFFTWExt
#   9 dependencies successfully precompiled in 13 seconds. 254 already precompiled.
#   1 dependency had output during precompilation:
# ┌ MKL_jll
# │   Downloading artifact: IntelOpenMP
# └

# %%
using FFTW

# %%
Pkg.add("DifferentialEquations")
# Out:
#    Resolving package versions...
#    Installed OrdinaryDiffEqRKN ─────────────────── v1.1.0
#    Installed DifferentialEquations ─────────────── v7.16.0
#    Installed OrdinaryDiffEqRosenbrock ──────────── v1.6.0
#    Installed FastGaussQuadrature ───────────────── v1.0.2
#    Installed StatsFuns ─────────────────────────── v1.3.2
#    Installed Accessors ─────────────────────────── v0.1.41
#    Installed OrdinaryDiffEqStabilizedRK ────────── v1.1.0
#    Installed AlmostBlockDiagonals ──────────────── v0.1.10
#    Installed OrdinaryDiffEqSDIRK ───────────────── v1.2.0
#    Installed BoundaryValueDiffEqFIRK ───────────── v1.5.0
#    Installed PDMats ────────────────────────────── v0.11.32
#    Installed TimerOutputs ──────────────────────── v0.5.27
#    Installed SciMLJacobianOperators ────────────── v0.1.1
#    Installed NonlinearSolve ────────────────────── v4.4.0
#    Installed OrdinaryDiffEqPRK ─────────────────── v1.1.0
#    Installed Polyester ─────────────────────────── v0.7.16
#    Installed Sundials_jll ──────────────────────── v5.2.3+0
#    Installed BoundaryValueDiffEqMIRK ───────────── v1.5.0
#    Installed EnumX ─────────────────────────────── v1.0.4
#    Installed CEnum ─────────────────────────────── v0.5.0
#    Installed MaybeInplace ──────────────────────── v0.1.4
#    Installed FunctionWrappers ──────────────────── v1.1.3
#    Installed OrdinaryDiffEqCore ────────────────── v1.18.1
#    Installed RecursiveArrayTools ───────────────── v3.29.0
#    Installed OrdinaryDiffEqSSPRK ───────────────── v1.2.0
#    Installed OrdinaryDiffEqAdamsBashforthMoulton ─ v1.2.0
#    Installed RandomNumbers ─────────────────────── v1.6.0
#    Installed Static ────────────────────────────── v1.1.1
#    Installed OrdinaryDiffEqVerner ──────────────── v1.1.1
#    Installed Distances ─────────────────────────── v0.10.12
#    Installed FiniteDiff ────────────────────────── v2.27.0
#    Installed BoundaryValueDiffEq ───────────────── v5.15.0
#    Installed MuladdMacro ───────────────────────── v0.2.4
#    Installed SteadyStateDiffEq ─────────────────── v2.4.1
#    Installed FastPower ─────────────────────────── v1.1.1
#    Installed SIMDTypes ─────────────────────────── v0.1.0
#    Installed BoundaryValueDiffEqCore ───────────── v1.7.0
#    Installed Functors ──────────────────────────── v0.5.2
#    Installed ArnoldiMethod ─────────────────────── v0.4.0
#    Installed SciMLBase ─────────────────────────── v2.74.1
#    Installed DiffEqBase ────────────────────────── v6.164.1
#    Installed CpuId ─────────────────────────────── v0.3.1
#    Installed SimpleUnPack ──────────────────────── v1.1.0
#    Installed OrdinaryDiffEqFIRK ────────────────── v1.7.0
#    Installed BandedMatrices ────────────────────── v1.9.1
#    Installed NonlinearSolveQuasiNewton ─────────── v1.2.0
#    Installed NLsolve ───────────────────────────── v4.5.1
#    Installed LinearSolve ───────────────────────── v3.3.1
#    Installed OrdinaryDiffEqNonlinearSolve ──────── v1.5.0
#    Installed ADTypes ───────────────────────────── v1.13.0
#    Installed BoundaryValueDiffEqMIRKN ──────────── v1.4.0
#    Installed BracketingNonlinearSolve ──────────── v1.1.0
#    Installed SimpleNonlinearSolve ──────────────── v2.1.0
#    Installed NonlinearSolveSpectralMethods ─────── v1.1.0
#    Installed ThreadingUtilities ────────────────── v0.5.2
#    Installed IfElse ────────────────────────────── v0.1.1
#    Installed DiffEqNoiseProcess ────────────────── v5.24.1
#    Installed LineSearch ────────────────────────── v0.1.4
#    Installed ManualMemory ──────────────────────── v0.1.8
#    Installed JumpProcesses ─────────────────────── v9.14.2
#    Installed SparseMatrixColorings ─────────────── v0.4.13
#    Installed NLSolversBase ─────────────────────── v7.8.3
#    Installed Random123 ─────────────────────────── v1.7.0
#    Installed LevyArea ──────────────────────────── v1.0.0
#    Installed Graphs ────────────────────────────── v1.12.0
#    Installed Rmath_jll ─────────────────────────── v0.5.1+0
#    Installed LazyArrays ────────────────────────── v2.6.0
#    Installed ExprTools ─────────────────────────── v0.1.10
#    Installed CommonSubexpressions ──────────────── v0.3.1
#    Installed CommonWorldInvalidations ──────────── v1.0.0
#    Installed MLStyle ───────────────────────────── v0.4.17
#    Installed OrdinaryDiffEq ────────────────────── v6.91.0
#    Installed FastAlmostBandedMatrices ──────────── v0.1.4
#    Installed StaticArrayInterface ──────────────── v1.8.0
#    Installed ArrayLayouts ──────────────────────── v1.11.1
#    Installed OrdinaryDiffEqLinear ──────────────── v1.1.0
#    Installed Expronicon ────────────────────────── v0.8.5
#    Installed MatrixFactorizations ──────────────── v3.0.1
#    Installed SciMLStructures ───────────────────── v1.6.1
#    Installed BitTwiddlingConvenienceFunctions ──── v0.1.6
#    Installed StochasticDiffEq ──────────────────── v6.74.0
#    Installed FunctionWrappersWrappers ──────────── v0.1.3
#    Installed OrdinaryDiffEqExplicitRK ──────────── v1.1.0
#    Installed GenericSchur ──────────────────────── v0.5.4
#    Installed Sundials ──────────────────────────── v4.26.1
#    Installed LayoutPointers ────────────────────── v0.1.17
#    Installed OrdinaryDiffEqQPRK ────────────────── v1.1.0
#    Installed OrdinaryDiffEqPDIRK ───────────────── v1.2.0
#    Installed OrdinaryDiffEqFunctionMap ─────────── v1.1.1
#    Installed OrdinaryDiffEqLowOrderRK ──────────── v1.2.0
#    Installed SciMLOperators ────────────────────── v0.3.12
#    Installed PositiveFactorizations ────────────── v0.2.4
#    Installed Inflate ───────────────────────────── v0.1.5
#    Installed NonlinearSolveBase ────────────────── v1.5.0
#    Installed DiffEqCallbacks ───────────────────── v4.3.0
#    Installed DelayDiffEq ───────────────────────── v5.52.0
#    Installed EnzymeCore ────────────────────────── v0.8.8
#    Installed FastClosures ──────────────────────── v0.3.2
#    Installed NonlinearSolveFirstOrder ──────────── v1.3.0
#    Installed BoundaryValueDiffEqShooting ───────── v1.5.0
#    Installed PolyesterWeave ────────────────────── v0.2.2
#    Installed ArrayInterface ────────────────────── v7.18.0
#    Installed LineSearches ──────────────────────── v7.3.0
#    Installed OrdinaryDiffEqExponentialRK ───────── v1.3.0
#    Installed PreallocationTools ────────────────── v0.4.25
#    Installed CloseOpenIntervals ────────────────── v0.1.13
#    Installed PackageExtensionCompat ────────────── v1.0.2
#    Installed OrdinaryDiffEqLowStorageRK ────────── v1.2.1
#    Installed OrdinaryDiffEqExtrapolation ───────── v1.4.0
#    Installed OrdinaryDiffEqStabilizedIRK ───────── v1.2.0
#    Installed OrdinaryDiffEqTsit5 ───────────────── v1.1.0
#    Installed ExponentialUtilities ──────────────── v1.27.0
#    Installed SimpleTraits ──────────────────────── v0.9.4
#    Installed Krylov ────────────────────────────── v0.9.10
#    Installed GPUArraysCore ─────────────────────── v0.2.0
#    Installed DifferentiationInterface ──────────── v0.6.42
#    Installed OrdinaryDiffEqBDF ─────────────────── v1.2.0
#    Installed StrideArraysCore ──────────────────── v0.5.7
#    Installed OrdinaryDiffEqDifferentiation ─────── v1.4.0
#    Installed Rmath ─────────────────────────────── v0.8.0
#    Installed OrdinaryDiffEqHighOrderRK ─────────── v1.1.0
#    Installed RuntimeGeneratedFunctions ─────────── v0.5.13
#    Installed OrdinaryDiffEqFeagin ──────────────── v1.1.0
#    Installed VertexSafeGraphs ──────────────────── v0.2.0
#    Installed ConcreteStructs ───────────────────── v0.2.3
#    Installed TruncatedStacktraces ──────────────── v1.4.0
#    Installed UnPack ────────────────────────────── v1.0.2
#    Installed InverseFunctions ──────────────────── v0.1.17
#    Installed PoissonRandom ─────────────────────── v0.4.4
#    Installed CPUSummary ────────────────────────── v0.2.6
#    Installed SymbolicIndexingInterface ─────────── v0.3.38
#    Installed BoundaryValueDiffEqAscher ─────────── v1.4.0
#    Installed ForwardDiff ───────────────────────── v0.10.38
#    Installed ResettableStacks ──────────────────── v1.1.1
#    Installed FillArrays ────────────────────────── v1.13.0
#    Installed Optim ─────────────────────────────── v1.11.0
#    Installed OrdinaryDiffEqSymplecticRK ────────── v1.3.0
#    Installed FastBroadcast ─────────────────────── v0.3.5
#    Installed OrdinaryDiffEqNordsieck ───────────── v1.1.0
#    Installed OrdinaryDiffEqDefault ─────────────── v1.3.0
#    Installed OrdinaryDiffEqIMEXMultistep ───────── v1.2.0
#    Installed Parameters ────────────────────────── v0.12.3
#    Installed SparseDiffTools ───────────────────── v2.23.1
#    Installed Distributions ─────────────────────── v0.25.117
#     Updating `C:\Users\kzaja\.julia\environments\v1.11\Project.toml`
#   [0c46a032] + DifferentialEquations v7.16.0
#     Updating `C:\Users\kzaja\.julia\environments\v1.11\Manifest.toml`
#  [47edcb42] + ADTypes v1.13.0
#   [7d9f7c33] + Accessors v0.1.41
#   [a95523ee] + AlmostBlockDiagonals v0.1.10
#   [ec485272] + ArnoldiMethod v0.4.0
#   [4fba245c] + ArrayInterface v7.18.0
#   [4c555306] + ArrayLayouts v1.11.1
#   [aae01518] + BandedMatrices v1.9.1
#   [62783981] + BitTwiddlingConvenienceFunctions v0.1.6
#   [764a87c0] + BoundaryValueDiffEq v5.15.0
#   [7227322d] + BoundaryValueDiffEqAscher v1.4.0
#   [56b672f2] + BoundaryValueDiffEqCore v1.7.0
#   [85d9eb09] + BoundaryValueDiffEqFIRK v1.5.0
#   [1a22d4ce] + BoundaryValueDiffEqMIRK v1.5.0
#   [9255f1d6] + BoundaryValueDiffEqMIRKN v1.4.0
#   [ed55bfe0] + BoundaryValueDiffEqShooting v1.5.0
#   [70df07ce] + BracketingNonlinearSolve v1.1.0
#   [fa961155] + CEnum v0.5.0
#   [2a0fbf3d] + CPUSummary v0.2.6
#   [fb6a15b2] + CloseOpenIntervals v0.1.13
#   [38540f10] + CommonSolve v0.2.4
#   [bbf7d656] + CommonSubexpressions v0.3.1
#   [f70d9fcc] + CommonWorldInvalidations v1.0.0
#   [a33af91c] + CompositionsBase v0.1.2
#   [2569d6c7] + ConcreteStructs v0.2.3
#   [adafc99b] + CpuId v0.3.1
#   [bcd4f6db] + DelayDiffEq v5.52.0
#   [2b5f629d] + DiffEqBase v6.164.1
#   [459566f4] + DiffEqCallbacks v4.3.0
#   [77a26b50] + DiffEqNoiseProcess v5.24.1
#   [163ba53b] + DiffResults v1.1.0
#   [b552c78f] + DiffRules v1.15.1
#   [0c46a032] + DifferentialEquations v7.16.0
#   [a0c0ee7d] + DifferentiationInterface v0.6.42
#   [b4f34e82] + Distances v0.10.12
#   [31c24e10] + Distributions v0.25.117
#   [4e289a0a] + EnumX v1.0.4
#   [f151be2c] + EnzymeCore v0.8.8
#   [d4d017d3] + ExponentialUtilities v1.27.0
#   [e2ba6199] + ExprTools v0.1.10
# ⌅ [6b7a57c9] + Expronicon v0.8.5
#   [9d29842c] + FastAlmostBandedMatrices v0.1.4
#   [7034ab61] + FastBroadcast v0.3.5
#   [9aa1b823] + FastClosures v0.3.2
#   [442a2c76] + FastGaussQuadrature v1.0.2
#   [a4df4552] + FastPower v1.1.1
#   [1a297f60] + FillArrays v1.13.0
#   [6a86dc24] + FiniteDiff v2.27.0
#   [f6369f11] + ForwardDiff v0.10.38
#   [069b7b12] + FunctionWrappers v1.1.3
#   [77dc65aa] + FunctionWrappersWrappers v0.1.3
#   [d9f16b24] + Functors v0.5.2
#   [46192b85] + GPUArraysCore v0.2.0
#   [c145ed77] + GenericSchur v0.5.4
#   [86223c79] + Graphs v1.12.0
#   [615f187c] + IfElse v0.1.1
#   [d25df0c9] + Inflate v0.1.5
#   [3587e190] + InverseFunctions v0.1.17
#   [ccbc3e58] + JumpProcesses v9.14.2
#   [ba0b0d4f] + Krylov v0.9.10
#   [10f19ff3] + LayoutPointers v0.1.17
#   [5078a376] + LazyArrays v2.6.0
#   [2d8b4e74] + LevyArea v1.0.0
#   [87fe0de2] + LineSearch v0.1.4
#   [d3d80556] + LineSearches v7.3.0
#   [7ed4a6bd] + LinearSolve v3.3.1
#   [d8e11817] + MLStyle v0.4.17
#   [d125e4d3] + ManualMemory v0.1.8
#   [a3b82374] + MatrixFactorizations v3.0.1
#   [bb5d69b7] + MaybeInplace v0.1.4
#   [46d2c3a1] + MuladdMacro v0.2.4
#   [d41bc354] + NLSolversBase v7.8.3
#   [2774e3e8] + NLsolve v4.5.1
#   [8913a72c] + NonlinearSolve v4.4.0
#   [be0214bd] + NonlinearSolveBase v1.5.0
#   [5959db7a] + NonlinearSolveFirstOrder v1.3.0
#   [9a2c21bd] + NonlinearSolveQuasiNewton v1.2.0
#   [26075421] + NonlinearSolveSpectralMethods v1.1.0
#   [429524aa] + Optim v1.11.0
#   [1dea7af3] + OrdinaryDiffEq v6.91.0
#   [89bda076] + OrdinaryDiffEqAdamsBashforthMoulton v1.2.0
#   [6ad6398a] + OrdinaryDiffEqBDF v1.2.0
#   [bbf590c4] + OrdinaryDiffEqCore v1.18.1
#   [50262376] + OrdinaryDiffEqDefault v1.3.0
#   [4302a76b] + OrdinaryDiffEqDifferentiation v1.4.0
#   [9286f039] + OrdinaryDiffEqExplicitRK v1.1.0
#   [e0540318] + OrdinaryDiffEqExponentialRK v1.3.0
#   [becaefa8] + OrdinaryDiffEqExtrapolation v1.4.0
#   [5960d6e9] + OrdinaryDiffEqFIRK v1.7.0
#   [101fe9f7] + OrdinaryDiffEqFeagin v1.1.0
#   [d3585ca7] + OrdinaryDiffEqFunctionMap v1.1.1
#   [d28bc4f8] + OrdinaryDiffEqHighOrderRK v1.1.0
#   [9f002381] + OrdinaryDiffEqIMEXMultistep v1.2.0
#   [521117fe] + OrdinaryDiffEqLinear v1.1.0
#   [1344f307] + OrdinaryDiffEqLowOrderRK v1.2.0
#   [b0944070] + OrdinaryDiffEqLowStorageRK v1.2.1
#   [127b3ac7] + OrdinaryDiffEqNonlinearSolve v1.5.0
#   [c9986a66] + OrdinaryDiffEqNordsieck v1.1.0
#   [5dd0a6cf] + OrdinaryDiffEqPDIRK v1.2.0
#   [5b33eab2] + OrdinaryDiffEqPRK v1.1.0
#   [04162be5] + OrdinaryDiffEqQPRK v1.1.0
#   [af6ede74] + OrdinaryDiffEqRKN v1.1.0
#   [43230ef6] + OrdinaryDiffEqRosenbrock v1.6.0
#   [2d112036] + OrdinaryDiffEqSDIRK v1.2.0
#   [669c94d9] + OrdinaryDiffEqSSPRK v1.2.0
#   [e3e12d00] + OrdinaryDiffEqStabilizedIRK v1.2.0
#   [358294b1] + OrdinaryDiffEqStabilizedRK v1.1.0
#   [fa646aed] + OrdinaryDiffEqSymplecticRK v1.3.0
#   [b1df2697] + OrdinaryDiffEqTsit5 v1.1.0
#   [79d7bb75] + OrdinaryDiffEqVerner v1.1.1
#   [90014a1f] + PDMats v0.11.32
#   [65ce6f38] + PackageExtensionCompat v1.0.2
#   [d96e819e] + Parameters v0.12.3
#   [e409e4f3] + PoissonRandom v0.4.4
#   [f517fe37] + Polyester v0.7.16
#   [1d0040c9] + PolyesterWeave v0.2.2
#   [85a6dd25] + PositiveFactorizations v0.2.4
#   [d236fae5] + PreallocationTools v0.4.25
#   [74087812] + Random123 v1.7.0
#   [e6cf234a] + RandomNumbers v1.6.0
#   [731186ca] + RecursiveArrayTools v3.29.0
#   [ae5879a3] + ResettableStacks v1.1.1
#   [79098fc4] + Rmath v0.8.0
#   [7e49a35a] + RuntimeGeneratedFunctions v0.5.13
#   [94e857df] + SIMDTypes v0.1.0
#   [0bca4576] + SciMLBase v2.74.1
#   [19f34311] + SciMLJacobianOperators v0.1.1
#   [c0aeaf25] + SciMLOperators v0.3.12
#   [53ae85a6] + SciMLStructures v1.6.1
#   [727e6d20] + SimpleNonlinearSolve v2.1.0
#   [699a6c99] + SimpleTraits v0.9.4
#   [ce78b400] + SimpleUnPack v1.1.0
#   [47a9eef4] + SparseDiffTools v2.23.1
#   [0a514795] + SparseMatrixColorings v0.4.13
#   [aedffcd0] + Static v1.1.1
#   [0d7ed370] + StaticArrayInterface v1.8.0
#   [4c63d2b9] + StatsFuns v1.3.2
#   [9672c7b4] + SteadyStateDiffEq v2.4.1
#   [789caeaf] + StochasticDiffEq v6.74.0
#   [7792a7ef] + StrideArraysCore v0.5.7
#   [c3572dad] + Sundials v4.26.1
#   [2efcf032] + SymbolicIndexingInterface v0.3.38
#   [8290d209] + ThreadingUtilities v0.5.2
#   [a759f4b9] + TimerOutputs v0.5.27
#   [781d530d] + TruncatedStacktraces v1.4.0
#   [3a884ed6] + UnPack v1.0.2
#   [19fa3120] + VertexSafeGraphs v0.2.0
#   [f50d1b31] + Rmath_jll v0.5.1+0
# ⌅ [fb77eaff] + Sundials_jll v5.2.3+0
#   [4607b0f0] + SuiteSparse
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#     665.7 ms  ✓ SimpleUnPack
#     642.6 ms  ✓ ConcreteStructs
#     612.3 ms  ✓ UnPack
#     664.2 ms  ✓ ExprTools
#     727.1 ms  ✓ InverseFunctions
#     989.3 ms  ✓ ADTypes
#     595.3 ms  ✓ CommonSolve
#    1194.0 ms  ✓ FunctionWrappers
#     662.2 ms  ✓ PackageExtensionCompat
#     784.6 ms  ✓ PoissonRandom
#     691.9 ms  ✓ ManualMemory
#     620.5 ms  ✓ EnumX
#     621.0 ms  ✓ IfElse
#     779.0 ms  ✓ Inflate
#     604.3 ms  ✓ CommonWorldInvalidations
#     593.2 ms  ✓ FastClosures
#    1483.5 ms  ✓ RandomNumbers
#     577.7 ms  ✓ MuladdMacro
#     601.8 ms  ✓ CEnum
#     525.5 ms  ✓ SIMDTypes
#     754.5 ms  ✓ PositiveFactorizations
#     571.6 ms  ✓ CompositionsBase
#     524.6 ms  ✓ FastPower
#    1317.7 ms  ✓ FillArrays
#    1464.3 ms  ✓ GenericSchur
#     845.5 ms  ✓ EnzymeCore
#     687.7 ms  ✓ DiffResults
#    1099.2 ms  ✓ Distances
#     768.9 ms  ✓ CommonSubexpressions
#     813.5 ms  ✓ SuiteSparse
#     970.1 ms  ✓ CpuId
#     710.9 ms  ✓ GPUArraysCore
#     764.0 ms  ✓ ArrayInterface
#    1061.4 ms  ✓ SimpleTraits
#     835.4 ms  ✓ TruncatedStacktraces
#     966.4 ms  ✓ Functors
#     887.7 ms  ✓ Rmath_jll
#     916.8 ms  ✓ DiffRules
#    1667.3 ms  ✓ Sundials_jll
#    1137.7 ms  ✓ ResettableStacks
#     682.5 ms  ✓ Parameters
#    1152.3 ms  ✓ LevyArea
#    1938.1 ms  ✓ ArnoldiMethod
#     709.8 ms  ✓ RuntimeGeneratedFunctions
#     734.9 ms  ✓ InverseFunctions → InverseFunctionsDatesExt
#    2773.5 ms  ✓ FastGaussQuadrature
#    2663.0 ms  ✓ AlmostBlockDiagonals
#     761.6 ms  ✓ LogExpFunctions → LogExpFunctionsInverseFunctionsExt
#    1178.5 ms  ✓ InverseFunctions → InverseFunctionsTestExt
#    1276.0 ms  ✓ Unitful → InverseFunctionsUnitfulExt
#    1098.4 ms  ✓ ADTypes → ADTypesChainRulesCoreExt
#     715.2 ms  ✓ ADTypes → ADTypesConstructionBaseExt
#    1604.4 ms  ✓ DifferentiationInterface
#     839.2 ms  ✓ FunctionWrappersWrappers
#    3560.2 ms  ✓ TimerOutputs
#    1965.7 ms  ✓ SparseMatrixColorings
#    8565.4 ms  ✓ Krylov
#     654.4 ms  ✓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#    1502.2 ms  ✓ ThreadingUtilities
#     689.1 ms  ✓ FillArrays → FillArraysStatisticsExt
#    1251.8 ms  ✓ Static
#    1301.4 ms  ✓ Random123
#     627.0 ms  ✓ EnzymeCore → AdaptExt
#     628.4 ms  ✓ ADTypes → ADTypesEnzymeCoreExt
#     964.3 ms  ✓ FillArrays → FillArraysSparseArraysExt
#     900.2 ms  ✓ Distances → DistancesSparseArraysExt
#     954.1 ms  ✓ Distances → DistancesChainRulesCoreExt
#     985.2 ms  ✓ MaybeInplace
#    1220.3 ms  ✓ PDMats
#     949.4 ms  ✓ ArrayInterface → ArrayInterfaceChainRulesCoreExt
#     650.2 ms  ✓ SciMLStructures
#     880.0 ms  ✓ ArrayInterface → ArrayInterfaceSparseArraysExt
#     630.7 ms  ✓ ArrayInterface → ArrayInterfaceGPUArraysCoreExt
#     614.1 ms  ✓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#    1257.3 ms  ✓ Rmath
#    1325.1 ms  ✓ DifferentiationInterface → DifferentiationInterfaceStaticArraysExt
#    1000.8 ms  ✓ DifferentiationInterface → DifferentiationInterfaceChainRulesCoreExt
#     904.9 ms  ✓ DifferentiationInterface → DifferentiationInterfaceSparseArraysExt
#    1381.6 ms  ✓ SparseMatrixColorings → SparseMatrixColoringsColorsExt
#    1280.7 ms  ✓ DifferentiationInterface → DifferentiationInterfaceSparseMatrixColoringsExt
#    4416.8 ms  ✓ SpecialPolynomials → SpecialPolynomialsFastGaussQuadratureExt
#     864.1 ms  ✓ BitTwiddlingConvenienceFunctions
#    5087.0 ms  ✓ ForwardDiff
#    1258.9 ms  ✓ MaybeInplace → MaybeInplaceSparseArraysExt
#    6832.0 ms  ✓ Graphs
#    3715.5 ms  ✓ Accessors
#    2384.5 ms  ✓ CPUSummary
#    1429.5 ms  ✓ FillArrays → FillArraysPDMatsExt
#    3147.2 ms  ✓ StaticArrayInterface
#    1256.5 ms  ✓ FiniteDiff
#    1339.7 ms  ✓ FastPower → FastPowerForwardDiffExt
#    2005.4 ms  ✓ ForwardDiff → ForwardDiffStaticArraysExt
#   22284.7 ms  ✓ MLStyle
#    1403.1 ms  ✓ PreallocationTools
#    2900.5 ms  ✓ StatsFuns
#    1346.8 ms  ✓ DifferentiationInterface → DifferentiationInterfaceForwardDiffExt
#    1305.0 ms  ✓ Accessors → TestExt
#    1097.6 ms  ✓ Accessors → LinearAlgebraExt
#    1421.0 ms  ✓ Accessors → StaticArraysExt
#    1905.3 ms  ✓ VertexSafeGraphs
#    1381.3 ms  ✓ Accessors → UnitfulExt
#     975.9 ms  ✓ PolyesterWeave
#    1038.9 ms  ✓ StaticArrayInterface → StaticArrayInterfaceOffsetArraysExt
#    1137.6 ms  ✓ CloseOpenIntervals
#    1437.2 ms  ✓ StaticArrayInterface → StaticArrayInterfaceStaticArraysExt
#     938.8 ms  ✓ FiniteDiff → FiniteDiffSparseArraysExt
#    1338.2 ms  ✓ LayoutPointers
#    1315.7 ms  ✓ FiniteDiff → FiniteDiffStaticArraysExt
#     832.7 ms  ✓ DifferentiationInterface → DifferentiationInterfaceFiniteDiffExt
#    1694.9 ms  ✓ NLSolversBase
#    1108.2 ms  ✓ StatsFuns → StatsFunsInverseFunctionsExt
#    2830.0 ms  ✓ StatsFuns → StatsFunsChainRulesCoreExt
#    2148.8 ms  ✓ SymbolicIndexingInterface
#    2666.9 ms  ✓ SciMLOperators
#   19872.2 ms  ✓ ArrayLayouts
#    1781.3 ms  ✓ StrideArraysCore
#    1198.5 ms  ✓ SciMLOperators → SciMLOperatorsStaticArraysCoreExt
#    2845.7 ms  ✓ LineSearches
#    1381.0 ms  ✓ SciMLOperators → SciMLOperatorsSparseArraysExt
#    3312.8 ms  ✓ RecursiveArrayTools
#    1131.9 ms  ✓ ArrayLayouts → ArrayLayoutsSparseArraysExt
#    7953.4 ms  ✓ Expronicon
#    7473.5 ms  ✓ Distributions
#    1607.7 ms  ✓ MatrixFactorizations
#    1321.6 ms  ✓ Polyester
#    1984.2 ms  ✓ NLsolve
#    1462.5 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsForwardDiffExt
#    1538.8 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsSparseArraysExt
#    1574.8 ms  ✓ TaylorSeries → TaylorSeriesRATExt
#    3641.0 ms  ✓ SparseDiffTools
#    4430.4 ms  ✓ Optim
#    2896.8 ms  ✓ LazyArrays
#    2177.8 ms  ✓ Distributions → DistributionsTestExt
#    1302.1 ms  ✓ FastBroadcast
#    2055.2 ms  ✓ Distributions → DistributionsChainRulesCoreExt
#    2536.9 ms  ✓ SparseDiffTools → SparseDiffToolsPolyesterExt
#    1409.2 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsFastBroadcastExt
#    1798.6 ms  ✓ LazyArrays → LazyArraysStaticArraysExt
#   12757.3 ms  ✓ SciMLBase
#   18755.8 ms  ✓ BandedMatrices
#    2180.5 ms  ✓ SciMLBase → SciMLBaseChainRulesCoreExt
#    1572.9 ms  ✓ FiniteDiff → FiniteDiffBandedMatricesExt
#    1626.6 ms  ✓ ArrayInterface → ArrayInterfaceBandedMatricesExt
#    1958.8 ms  ✓ BandedMatrices → BandedMatricesSparseArraysExt
#    1770.4 ms  ✓ MatrixFactorizations → MatrixFactorizationsBandedMatricesExt
#    4947.6 ms  ✓ SciMLJacobianOperators
#    2662.1 ms  ✓ LazyArrays → LazyArraysBandedMatricesExt
#    7480.2 ms  ✓ DiffEqBase
#    2370.2 ms  ✓ DiffEqBase → DiffEqBaseChainRulesCoreExt
#    2933.8 ms  ✓ DiffEqBase → DiffEqBaseForwardDiffExt
#    5991.3 ms  ✓ LineSearch
#    2802.1 ms  ✓ DiffEqBase → DiffEqBaseSparseArraysExt
#    3206.6 ms  ✓ DiffEqBase → DiffEqBaseDistributionsExt
#    2890.9 ms  ✓ DiffEqBase → DiffEqBaseUnitfulExt
#    9576.4 ms  ✓ NonlinearSolveBase
#    2387.8 ms  ✓ LineSearch → LineSearchLineSearchesExt
#   11595.5 ms  ✓ FastAlmostBandedMatrices
#    6018.5 ms  ✓ DiffEqCallbacks
#    6162.4 ms  ✓ OrdinaryDiffEqCore
#    2577.7 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseSparseMatrixColoringsExt
#    5193.3 ms  ✓ JumpProcesses
#    2918.7 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseForwardDiffExt
#    5403.5 ms  ✓ DiffEqNoiseProcess
#    2614.3 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseSparseArraysExt
#    3457.4 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseBandedMatricesExt
#    2826.4 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseLineSearchExt
#    3496.6 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseDiffEqBaseExt
#    3004.7 ms  ✓ OrdinaryDiffEqCore → OrdinaryDiffEqCoreEnzymeCoreExt
#    5463.5 ms  ✓ SteadyStateDiffEq
#   59496.4 ms  ✓ ExponentialUtilities
#    8274.0 ms  ✓ BracketingNonlinearSolve
#    3599.6 ms  ✓ OrdinaryDiffEqFunctionMap
#    4603.3 ms  ✓ OrdinaryDiffEqPRK
#   21273.9 ms  ✓ Sundials
#    4504.4 ms  ✓ OrdinaryDiffEqExplicitRK
#    5270.3 ms  ✓ OrdinaryDiffEqStabilizedRK
#   12375.8 ms  ✓ NonlinearSolveSpectralMethods
#    4345.1 ms  ✓ OrdinaryDiffEqRKN
#    3967.6 ms  ✓ OrdinaryDiffEqQPRK
#    5597.6 ms  ✓ OrdinaryDiffEqSSPRK
#   10899.0 ms  ✓ OrdinaryDiffEqTsit5
#    4649.1 ms  ✓ OrdinaryDiffEqHighOrderRK
#    4071.4 ms  ✓ OrdinaryDiffEqSymplecticRK
#    2356.9 ms  ✓ ExponentialUtilities → ExponentialUtilitiesStaticArraysExt
#    3818.7 ms  ✓ OrdinaryDiffEqFeagin
#    2207.6 ms  ✓ BracketingNonlinearSolve → BracketingNonlinearSolveForwardDiffExt
#    5821.0 ms  ✓ OrdinaryDiffEqLowOrderRK
#    5305.9 ms  ✓ OrdinaryDiffEqLowStorageRK
#    2455.2 ms  ✓ NonlinearSolveSpectralMethods → NonlinearSolveSpectralMethodsForwardDiffExt
#    2844.7 ms  ✓ OrdinaryDiffEqNordsieck
#    3167.5 ms  ✓ OrdinaryDiffEqAdamsBashforthMoulton
#   10076.6 ms  ✓ SimpleNonlinearSolve
#    1742.7 ms  ✓ SimpleNonlinearSolve → SimpleNonlinearSolveChainRulesCoreExt
#    1836.1 ms  ✓ SimpleNonlinearSolve → SimpleNonlinearSolveDiffEqBaseExt
#   36395.3 ms  ✓ OrdinaryDiffEqVerner
#    2449.7 ms  ✓ OrdinaryDiffEqLinear
#  105288.1 ms  ✓ LinearSolve
#    2928.5 ms  ✓ LinearSolve → LinearSolveEnzymeExt
#    3032.0 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseLinearSolveExt
#    3450.9 ms  ✓ LinearSolve → LinearSolveBandedMatricesExt
#    3773.7 ms  ✓ LinearSolve → LinearSolveFastAlmostBandedMatricesExt
#    5136.2 ms  ✓ LinearSolve → LinearSolveSparseArraysExt
#    4187.4 ms  ✓ OrdinaryDiffEqDifferentiation
#    6271.5 ms  ✓ OrdinaryDiffEqExtrapolation
#   12504.0 ms  ✓ NonlinearSolveQuasiNewton
#    3047.6 ms  ✓ NonlinearSolveQuasiNewton → NonlinearSolveQuasiNewtonForwardDiffExt
#   20168.2 ms  ✓ NonlinearSolveFirstOrder
#   19471.8 ms  ✓ OrdinaryDiffEqRosenbrock
#    6071.1 ms  ✓ BoundaryValueDiffEqCore
#   13236.9 ms  ✓ NonlinearSolve
#    7609.7 ms  ✓ BoundaryValueDiffEqAscher
#    8423.2 ms  ✓ BoundaryValueDiffEqMIRKN
#    5159.2 ms  ✓ NonlinearSolve → NonlinearSolveNLsolveExt
#    5242.8 ms  ✓ NonlinearSolve → NonlinearSolveSundialsExt
#    6819.8 ms  ✓ OrdinaryDiffEqNonlinearSolve
#    7881.0 ms  ✓ OrdinaryDiffEqIMEXMultistep
#    8172.6 ms  ✓ OrdinaryDiffEqStabilizedIRK
#    8624.3 ms  ✓ OrdinaryDiffEqPDIRK
#   10095.1 ms  ✓ OrdinaryDiffEqSDIRK
#   12319.0 ms  ✓ StochasticDiffEq
#    6289.4 ms  ✓ OrdinaryDiffEqExponentialRK
#   14862.2 ms  ✓ OrdinaryDiffEqBDF
#   20838.8 ms  ✓ OrdinaryDiffEqFIRK
#   25388.1 ms  ✓ OrdinaryDiffEqDefault
#    9944.8 ms  ✓ OrdinaryDiffEq
#   79724.1 ms  ✓ BoundaryValueDiffEqMIRK
#    8196.1 ms  ✓ BoundaryValueDiffEqShooting
#    8445.1 ms  ✓ DelayDiffEq
#  117573.3 ms  ✓ BoundaryValueDiffEqFIRK
#    7924.5 ms  ✓ BoundaryValueDiffEq
#    9563.5 ms  ✓ DifferentialEquations
#   231 dependencies successfully precompiled in 326 seconds. 263 already precompiled.
#   1 dependency had output during precompilation:
# ┌ LinearSolve
# │   Downloading artifact: MKL
# └

# %%
using DifferentialEquations

# %%
Pkg.add("Roots")
# Out:
#    Resolving package versions...
#    Installed Roots ─ v2.2.5
#     Updating `C:\Users\kzaja\.julia\environments\v1.11\Project.toml`
#   [f2b01f46] + Roots v2.2.5
#     Updating `C:\Users\kzaja\.julia\environments\v1.11\Manifest.toml`
#  [f2b01f46] + Roots v2.2.5
# Precompiling project...
#    2434.2 ms  ✓ Roots
#     708.6 ms  ✓ Roots → RootsChainRulesCoreExt
#     857.1 ms  ✓ Roots → RootsForwardDiffExt
#   3 dependencies successfully precompiled in 5 seconds. 494 already precompiled.

# %%
using Roots

# %%
Pkg.add("ForwardDiff")
# Out:
#    Resolving package versions...
#     Updating `C:\Users\kzaja\.julia\environments\v1.11\Project.toml`
#   [f6369f11] + ForwardDiff v0.10.38
#   No Changes to `C:\Users\kzaja\.julia\environments\v1.11\Manifest.toml`

# %%
using ForwardDiff
